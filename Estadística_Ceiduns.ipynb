# %% [markdown]
# **Importando Librerias**

# %%
import seaborn as sns
import pandas as pd
df = pd.read_csv('2018_notas_ceiduns_Julio.csv')

# %% [markdown]
# **Preprocesamiento de Datos - Verificar la existencia de datos perdidos**

# %%
# Verificar existencia de datos perdidos
sns.heatmap(df.isnull(), cbar=False)
df.isnull().sum()
# Out:
# N                       0
# Apellidos y Nombres     0
# Pago Siguiente mes      0
# Listening               0
# Reading                 0
# Writing                 0
# Media                   0
# Speak                   0
# Middle Exam.            0
# Final Exam              0
# Final Mark              1
# dtype: int64

# %% [markdown]
# **Preprocesamiento de Datos - Inputación de datos perdidos**

# %%
# Inputación de valores perdidos
# En caso de variables categóricas, utilizamos la Moda. Caso contrario, utilizaremos la media

# En este caso, como es manejable el dato perdido de la nota final en la fila del estudiante que no asistió a clases, la imputamos con 0
df['Final Mark'].fillna(0, inplace=True)
df
# Out:
#      N Apellidos y Nombres   ...  Final Exam  Final Mark
# 0    1                   JF  ...           0         0.0
# 1    2                   RR  ...           0         0.0
# 2    3                   MM  ...           8        11.8
# 3    4                   TM  ...          15        14.8
# 4    5                   VA  ...           0         0.0
# 5    6                   AA  ...          18        15.3
# 6    7                   GE  ...          12        14.5
# 7    8                   KE  ...          15        16.0
# 8    9                   PN  ...           0         0.0
# 9   10                    E  ...          15        12.8
# 10  11                   AF  ...          17        15.0
# 11  12                   MA  ...           7        11.5
# 12  13                   CD  ...          11        12.3
# 13  14                   JA  ...           5         9.3
# 14  15                   CF  ...          11        12.0
# ...

# %% [markdown]
# **Calcular la Media, Mediana y Moda de las notas finales**

# %%
# La media es la suma de N elementos dividido entre N, es susceptible a los extremos
# La mediana es el valor dentro del conjunto de datos que es menor que el 50% de los datos y mayor que el 50% restante (Valor Central)
# La moda es el valor mas repetido
media = df["Final Mark"].mean()
mediana = df["Final Mark"].median()
moda = df["Final Mark"].mode()
print("""
    Media: %d
    Mediana: %d
    Moda: %d
""" % (media,mediana,moda))
# Out:
#     Media: 11
#     Mediana: 12
#     Moda: 0

# %% [markdown]
# **¿Cuál es la nota que tiene como mínimo el 10% más nota de la clase?***

# %%
# Los cuartiles abarcan el 25%, 50% y 75% de las observaciones. Los percentiles son una generalización con cualquier porcentaje
p90 = df["Final Mark"].quantile(0.9)
p90

# Los cuartiles dividen el dato en 4 partes iguales (1/4 de los datos o  25%)
# El segundo cuartil coincide con la mediana

# El Decil divide los datos en 10 partes iguales
# El Perceptil dibide los datos en 100 partes iguales

# El Perceptil 90 contiene el 10% de los datos
# El resultado de que el 10% con mas nota de la clase ha sacado como minimo 15.3
# Out:
# 15.3
